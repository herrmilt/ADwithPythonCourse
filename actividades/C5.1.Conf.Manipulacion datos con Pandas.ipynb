# %% [markdown]
# # Manipulación de datos con Pandas
# Pandas es una biblioteca de código abierto construida sobre NumPy. Se despliega como paquete de Pandas ofreciendo varios tipos de datos y operaciones para manipular datos numéricos y series numéricas.

# %%
# Importar los paquetes
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series
# Una serie es un arreglo unidimensional con un indice. Este arreglo puede almacenar cualquier tipo de datos.

# %%
ser = pd.Series(dtype=np.float64)
print(ser)
print(ser.__class__)
# Out:
# Series([], dtype: float64)
# <class 'pandas.core.series.Series'>

# %%
a = [1, 7, 2]
s = pd.Series(a)
s
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# Cada valor de una serie tiene un indice (puede estar repetido) que lo identifica
s[0], s[1], s[2]
# Out:
# (1, 7, 2)

# %%
# El indice puede especificarse (si no se especifica el indice, este se genera automaticamente como autonumerico)
s2 = pd.Series([2, 5, 8], index=['a', 'c', 'x'])
s2
# Out:
# a    2
# c    5
# x    8
# dtype: int64

# %%
# El acceso es por el indice
s2['a'], s2['c'], s2['x']
# Out:
# (2, 5, 8)

# %%
# Si el valor del indice esta duplicado ...
s2 = pd.Series([2, 5, 8, 13], index=['a', 'c', 'x', 'a'])
print(s2['a'])
print(s2['a'].__class__)
# Out:
# a     2
# a    13
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Inicializar usando un diccionario
calories = {"day1": 420, "day2": 380, "day3": 390}
pd.Series(calories)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
# Si se asigna un indice, solamente los valores en el indice se crearan
calories = {"day1": 420, "day2": 380, "day3": 390}
pd.Series(calories, index = ['day1', 'day2'])
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ## DataFrames

# %% [markdown]
# Un DataFrame es una tabla bidimensional, de tamaño variable, y potencialmente heterogénea. Al igual que las Series, cada fila tiene un índice. Cada columna de la tabla también tiene un índice.

# %%
df_airplane = pd.read_csv('data/3-Airplane_Crashes_Since_1908.txt')
df_airplane
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 0                Military - U.S. Army      NaN
# 1                Military - U.S. Navy      NaN
# 2                             Private        -
# 3              Military - German Navy      NaN
# 4              Military - German Navy      NaN
# ...                               ...      ...
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 0                                 Demonstration
# 1                                   Test flight
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 0                     Wright Flyer III          NaN     1     2.0         1.0
# 1                            Dirigible          NaN   NaN     5.0         5.0
# 2                     Curtiss seaplane          NaN   NaN     1.0         1.0
# 3               Zeppelin L-1 (airship)          NaN   NaN    20.0        14.0
# 4               Zeppelin L-2 (airship)          NaN   NaN    30.0        30.0
# ...                                ...          ...   ...     ...         ...
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 0        0.0  During a demonstration flight, a U.S. Army fly...
# 1        0.0  First U.S. dirigible Akron exploded just offsh...
# 2        0.0  The first fatal airplane accident in Canada oc...
# 3        0.0  The airship flew into a thunderstorm and encou...
# 4        0.0  Hydrogen gas which was being vented was sucked...
# ...      ...                                                ...
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...
#
# [5268 rows x 13 columns]

# %%
# Noten, todos son indices
print(df_airplane.index)
print(df_airplane.columns)
# Out:
# RangeIndex(start=0, stop=5268, step=1)
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
# No hay diferencias entre filas y columnas ...
trasposed = df_airplane.T
trasposed
# Out:
#                                                            0     \
# Date                                                 09/17/1908
# Time                                                      17:18
# Location                                    Fort Myer, Virginia
# Operator                                   Military - U.S. Army
# Flight #                                                    NaN
# Route                                             Demonstration
# Type                                           Wright Flyer III
# Registration                                                NaN
# cn/In                                                         1
# Aboard                                                      2.0
# Fatalities                                                  1.0
# Ground                                                      0.0
# Summary       During a demonstration flight, a U.S. Army fly...
#
#                                                            1     \
# Date                                                 07/12/1912
# Time                                                      06:30
# Location                                AtlantiCity, New Jersey
# Operator                                   Military - U.S. Navy
# Flight #                                                    NaN
# Route                                               Test flight
# Type                                                  Dirigible
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                      5.0
# Fatalities                                                  5.0
# Ground                                                      0.0
# Summary       First U.S. dirigible Akron exploded just offsh...
#
#                                                            2     \
# Date                                                 08/06/1913
# Time                                                        NaN
# Location                     Victoria, British Columbia, Canada
# Operator                                                Private
# Flight #                                                      -
# Route                                                       NaN
# Type                                           Curtiss seaplane
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                      1.0
# Fatalities                                                  1.0
# Ground                                                      0.0
# Summary       The first fatal airplane accident in Canada oc...
#
#                                                            3     \
# Date                                                 09/09/1913
# Time                                                      18:30
# Location                                     Over the North Sea
# Operator                                 Military - German Navy
# Flight #                                                    NaN
# Route                                                       NaN
# Type                                     Zeppelin L-1 (airship)
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                     20.0
# Fatalities                                                 14.0
# Ground                                                      0.0
# Summary       The airship flew into a thunderstorm and encou...
#
#                                                            4     \
# Date                                                 10/17/1913
# Time                                                      10:30
# Location                             Near Johannisthal, Germany
# Operator                                 Military - German Navy
# Flight #                                                    NaN
# Route                                                       NaN
# Type                                     Zeppelin L-2 (airship)
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                     30.0
# Fatalities                                                 30.0
# Ground                                                      0.0
# Summary       Hydrogen gas which was being vented was sucked...
#
#                                                            5     \
# Date                                                 03/05/1915
# Time                                                      01:00
# Location                                        Tienen, Belgium
# Operator                                 Military - German Navy
# Flight #                                                    NaN
# Route                                                       NaN
# Type                                     Zeppelin L-8 (airship)
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                     41.0
# Fatalities                                                 21.0
# Ground                                                      0.0
# Summary       Crashed into trees while attempting to land af...
#
#                                                            6     \
# Date                                                 09/03/1915
# Time                                                      15:20
# Location                                  Off Cuxhaven, Germany
# Operator                                 Military - German Navy
# Flight #                                                    NaN
# Route                                                       NaN
# Type                                    Zeppelin L-10 (airship)
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                     19.0
# Fatalities                                                 19.0
# Ground                                                      0.0
# Summary       Exploded and burned near Neuwerk Island,  when...
#
#                                                     7     \
# Date                                          07/28/1916
# Time                                                 NaN
# Location                           Near Jambol, Bulgeria
# Operator                          Military - German Army
# Flight #                                             NaN
# Route                                                NaN
# Type                       Schutte-Lanz S-L-10 (airship)
# Registration                                         NaN
# cn/In                                                NaN
# Aboard                                              20.0
# Fatalities                                          20.0
# Ground                                               0.0
# Summary       Crashed near the Black Sea, cause unknown.
#
#                                                            8     \
# Date                                                 09/24/1916
# Time                                                      01:00
# Location                                    Billericay, England
# Operator                                 Military - German Navy
# Flight #                                                    NaN
# Route                                                       NaN
# Type                                    Zeppelin L-32 (airship)
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                     22.0
# Fatalities                                                 22.0
# Ground                                                      0.0
# Summary       Shot down by British aircraft crashing in flames.
#
#                                                            9     ...  \
# Date                                                 10/01/1916  ...
# Time                                                      23:45  ...
# Location                                   Potters Bar, England  ...
# Operator                                 Military - German Navy  ...
# Flight #                                                    NaN  ...
# Route                                                       NaN  ...
# Type                                    Zeppelin L-31 (airship)  ...
# Registration                                                NaN  ...
# cn/In                                                       NaN  ...
# Aboard                                                     19.0  ...
# Fatalities                                                 19.0  ...
# Ground                                                      0.0  ...
# Summary       Shot down in flames by the British 39th Home D...  ...
#
#                                                            5258  \
# Date                                                 04/09/2009
# Time                                                      07:00
# Location                                 Near Wamena, Indonesia
# Operator                                       Aviastar Mandiri
# Flight #                                                    NaN
# Route                                         Jayapura - Wamena
# Type                              British Aerospace BAe-146-300
# Registration                                             PK-BRD
# cn/In                                                     E3189
# Aboard                                                      6.0
# Fatalities                                                  6.0
# Ground                                                      0.0
# Summary       The cargo plane crashed into Gunung Pike mount...
#
#                                                            5259  \
# Date                                                 04/17/2009
# Time                                                      10:30
# Location                               Mount Gergaji, Indonesia
# Operator                                             Mimika Air
# Flight #                                                    514
# Route                                             Ilaga - Mulia
# Type                                               Pilatus PC-6
# Registration                                             PK-LTJ
# cn/In                                                       959
# Aboard                                                     11.0
# Fatalities                                                 11.0
# Ground                                                      0.0
# Summary       The passenger plane crashed in poor weather in...
#
#                                                            5260  \
# Date                                                 04/17/2009
# Time                                                      15:32
# Location                       Canaima National Park, Venezuela
# Operator                                        Aerotuy airline
# Flight #                                                    NaN
# Route                                        Canaima - Porlamar
# Type                                  Cessna 208B Grand Caravan
# Registration                                            YV-1181
# cn/In                                                 208B-0695
# Aboard                                                     11.0
# Fatalities                                                  1.0
# Ground                                                      0.0
# Summary       The plane, carrying 9 tourists, crashed 5 mile...
#
#                                                            5261  \
# Date                                                 04/29/2009
# Time                                                      06:00
# Location                     Massamba, DemocratiRepubliof Congo
# Operator                                               Bako Air
# Flight #                                                    NaN
# Route         Bangui, CAR- Brazzaville, Congo - Harare, Zimb...
# Type                                           Boeing B-737-200
# Registration                                            TL-ADM
# cn/In                                                 22264/753
# Aboard                                                      7.0
# Fatalities                                                  7.0
# Ground                                                      0.0
# Summary       Crashed while en route on a ferrying flight. T...
#
#                                                            5262  \
# Date                                                 05/03/2009
# Time                                                      12:00
# Location                       Near El Alto de Rubio, Venezuela
# Operator                             Military - Venezuelan Army
# Flight #                                                    NaN
# Route                                                    Patrol
# Type                                                      Mi-35
# Registration                                           EV08114
# cn/In                                                       NaN
# Aboard                                                     18.0
# Fatalities                                                 18.0
# Ground                                                      0.0
# Summary       The helicopter was patrolling along the Venezu...
#
#                                                            5263  \
# Date                                                 05/20/2009
# Time                                                      06:30
# Location                                 Near Madiun, Indonesia
# Operator                        Military - Indonesian Air Force
# Flight #                                                    NaN
# Route                                          Jakarta - Maduin
# Type                                    Lockheed C-130 Hercules
# Registration                                             A-1325
# cn/In                                                      1982
# Aboard                                                    112.0
# Fatalities                                                 98.0
# Ground                                                      2.0
# Summary       While on approach, the military transport cras...
#
#                                                            5264  \
# Date                                                 05/26/2009
# Time                                                        NaN
# Location                      Near Isiro, DemocratiRepubliCongo
# Operator                                            Service Air
# Flight #                                                    NaN
# Route                                              Goma - Isiro
# Type                                              Antonov An-26
# Registration                                             9Q-CSA
# cn/In                                                      5005
# Aboard                                                      4.0
# Fatalities                                                  4.0
# Ground                                                      NaN
# Summary       The cargo plane crashed while on approach to I...
#
#                                                            5265  \
# Date                                                 06/01/2009
# Time                                                      00:15
# Location      AtlantiOcean, 570 miles northeast of Natal, Br...
# Operator                                             Air France
# Flight #                                                    447
# Route                                    Rio de Janeiro - Paris
# Type                                            Airbus A330-203
# Registration                                             F-GZCP
# cn/In                                                       660
# Aboard                                                    228.0
# Fatalities                                                228.0
# Ground                                                      0.0
# Summary       The Airbus went missing over the AtlantiOcean ...
#
#                                                            5266  \
# Date                                                 06/07/2009
# Time                                                      08:30
# Location           Near Port Hope Simpson, Newfoundland, Canada
# Operator                                             Strait Air
# Flight #                                                    NaN
# Route                 Lourdes de BlanSablon - Port Hope Simpson
# Type                           Britten-Norman BN-2A-27 Islander
# Registration                                            C-FJJR
# cn/In                                                       424
# Aboard                                                      1.0
# Fatalities                                                  1.0
# Ground                                                      0.0
# Summary       The air ambulance crashed into hills while att...
#
#                                                            5267
# Date                                                 06/08/2009
# Time                                                        NaN
# Location                      State of Arunachal Pradesh, India
# Operator                            Military - Indian Air Force
# Flight #                                                    NaN
# Route                                        Mechuka for Jorhat
# Type                                              Antonov An-32
# Registration                                                NaN
# cn/In                                                       NaN
# Aboard                                                     13.0
# Fatalities                                                 13.0
# Ground                                                      0.0
# Summary       The military transport went missing while en r...
#
# [13 rows x 5268 columns]

# %%
print(trasposed.index)
print(trasposed.columns)
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')
# RangeIndex(start=0, stop=5268, step=1)

# %%
# Accediendo a una columna
df_airplane['Operator']
# Out:
# 0                  Military - U.S. Army
# 1                  Military - U.S. Navy
# 2                               Private
# 3                Military - German Navy
# 4                Military - German Navy
#                      ...
# 5263    Military - Indonesian Air Force
# 5264                        Service Air
# 5265                         Air France
# 5266                         Strait Air
# 5267        Military - Indian Air Force
# Name: Operator, Length: 5268, dtype: object

# %%
print(df_airplane['Operator'].__class__)
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Acceso a una fila por su indice
df_airplane.iloc[5263,:]
# Out:
# Date                                                   05/20/2009
# Time                                                        06:30
# Location                                   Near Madiun, Indonesia
# Operator                          Military - Indonesian Air Force
# Flight #                                                      NaN
# Route                                            Jakarta - Maduin
# Type                                      Lockheed C-130 Hercules
# Registration                                               A-1325
# cn/In                                                        1982
# Aboard                                                      112.0
# Fatalities                                                   98.0
# Ground                                                        2.0
# Summary         While on approach, the military transport cras...
# Name: 5263, dtype: object

# %%
# Inicializando un DataFrame con diccionario
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
# Acceder a una fila por el indice
print(df.loc[1])
print(df.loc[1].__class__)
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Recordar: El indice puede tener cualquier tipo de datos
trasposed.loc['Location']
# Out:
# 0                                     Fort Myer, Virginia
# 1                                 AtlantiCity, New Jersey
# 2                      Victoria, British Columbia, Canada
# 3                                      Over the North Sea
# 4                              Near Johannisthal, Germany
#                               ...
# 5263                               Near Madiun, Indonesia
# 5264                    Near Isiro, DemocratiRepubliCongo
# 5265    AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266         Near Port Hope Simpson, Newfoundland, Canada
# 5267                    State of Arunachal Pradesh, India
# Name: Location, Length: 5268, dtype: object

# %%
trasposed.iloc[1]
# Out:
# 0       17:18
# 1       06:30
# 2         NaN
# 3       18:30
# 4       10:30
#         ...
# 5263    06:30
# 5264      NaN
# 5265    00:15
# 5266    08:30
# 5267      NaN
# Name: Time, Length: 5268, dtype: object

# %%
# Cargando un DataFrame de un diccionario
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

pd.DataFrame(data)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
# Noten que no se usa el orden (que no hay en diccionarios), sino el indice
data = {
    "nombre":{
        1: "Pedro",
        2: "Juan",
        3: "Maria"
    },
    "edad": {
        1: 23,
        2: 34,
        4: 15
    },
    "masculino":{
        1: True,
        3: False,
        4: True,
    }
}
pd.DataFrame(data)
# Out:
#   nombre  edad masculino
# 1  Pedro  23.0      True
# 2   Juan  34.0       NaN
# 3  Maria   NaN     False
# 4    NaN  15.0      True

# %%
# Primeras y ultimas lineas
df_airplane.head(5)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df_airplane.tail(5)
# Out:
#             Date   Time                                           Location  \
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...

# %%
# En ambos casos el resultado es un DataFrame
df_airplane.tail(5).__class__
# Out:
# pandas.core.frame.DataFrame

# %%
# Informacion sobre el DataFrame
# Noten: Nombre, tipo, cantidad de datos vacios
df_airplane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %% [markdown]
# ## Limpieza de datos
# Para mostrar cómo limpiar los datos, utilizaremos la siguiente bd de ejemplo, con los siguientes problemas:
# - Faltan datos en algunas celdas (fecha en fila 22 y calorias en las filas 18 y 28)
# - Algunos datos tienen formato erroneo (Fecha en la 26)
# - Algunos datos son erroneps (Diración en 7)
# - Filas duplicadas (fila 11 y 12)

# %%
data = pd.read_csv("data/cardio.csv")
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 18        45  '2020/12/18'     90       112       NaN
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60    12/26/2020    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
# Eliminar filas con valores faltantes
# Noten que los indices no cambiaron!
new_data = data.dropna()
new_data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60    12/26/2020    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %% [markdown]
# ** Nota importante **
# -  Toda transformación crea un DataFrame nuevo con la modificación

# %%
print(data.shape)
print(new_data.shape)
# Out:
# (32, 5)
# (29, 5)

# %% [markdown]
# - Esto puede cambiarse en casi todos los casos con el parametro inplace=True

# %%
data_copy = pd.read_csv("data/cardio.csv")
print(data_copy.shape)
data_copy.dropna(inplace=True)
print(data_copy.shape)

# %%
# Otra forma de completar valores perdidos
df = pd.read_csv('data/cardio.csv')
df.fillna(130, inplace = True) 
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 18        45  '2020/12/18'     90       112     130.0
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           130    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60    12/26/2020    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132     130.0
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
# Hay que tener cuidado, pues el cambio se hace en todas las columnas. Mejor
df = pd.read_csv('data/cardio.csv')
df['Calories'].fillna(130, inplace = True) 
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 18        45  '2020/12/18'     90       112     130.0
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60    12/26/2020    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132     130.0
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
# Remplazar por media, mediana o moda
df = pd.read_csv('data/cardio.csv')
# or .median() or .mode()[0] (la moda devuelve una serie)
mean = df['Calories'].mean()
print(mean)
df['Calories'].fillna(mean, inplace = True) 
df
# Out:
# 304.68
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# 16        60  '2020/12/16'     98       120    215.20
# 17        60  '2020/12/17'    100       120    300.00
# 18        45  '2020/12/18'     90       112    304.68
# 19        60  '2020/12/19'    103       123    323.00
# 20        45  '2020/12/20'     97       125    243.00
# 21        60  '2020/12/21'    108       131    364.20
# 22        45           NaN    100       119    282.00
# 23        60  '2020/12/23'    130       101    300.00
# 24        45  '2020/12/24'    105       132    246.00
# 25        60  '2020/12/25'    102       126    334.50
# 26        60    12/26/2020    100       120    250.00
# 27        60  '2020/12/27'     92       118    241.00
# 28        60  '2020/12/28'    103       132    304.68
# 29        60  '2020/12/29'    100       132    280.00
# 30        60  '2020/12/30'    102       129    380.30
# 31        60  '2020/12/31'     92       115    243.00

# %%
# Convirtiendo las cadenas al formato correcto. La columna Date es un datetime
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7        450 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# 18        45 2020-12-18     90       112    304.68
# 19        60 2020-12-19    103       123    323.00
# 20        45 2020-12-20     97       125    243.00
# 21        60 2020-12-21    108       131    364.20
# 22        45        NaT    100       119    282.00
# 23        60 2020-12-23    130       101    300.00
# 24        45 2020-12-24    105       132    246.00
# 25        60 2020-12-25    102       126    334.50
# 26        60 2020-12-26    100       120    250.00
# 27        60 2020-12-27     92       118    241.00
# 28        60 2020-12-28    103       132    304.68
# 29        60 2020-12-29    100       132    280.00
# 30        60 2020-12-30    102       129    380.30
# 31        60 2020-12-31     92       115    243.00

# %%
# Noten que todo se resuelve, menos el valor faltante ... NaT
# Como esto no tiene solucion en este caso, eliminamos esa fila
df.dropna(subset=['Date'], inplace = True)
df

# %% [markdown]
# Los datos erroneos no están vacíos o en un formato incorrecto, sino que son producto de errores al captarlos o al digitalizar la información. Por ejemplo, una temperatura máxima en Cuba en Agosto de 3 grados es muy probablemente un error.
#
# En la base de datos que procesamos, el valor de 450 en duration es un error. Se agrego un cero

# %%
df.loc[0:7, 'Duration']

# %%
# La base de datos pequeña, correcciones a mano ...
df.loc[7, 'Duration'] = 45
df.loc[0:7, 'Duration']
# Out:
# 0    60
# 1    60
# 2    60
# 3    45
# 4    45
# 5    60
# 6    60
# 7    45
# Name: Duration, dtype: int64

# %%
# Busqueda de errores:
df.describe()
# Out:
#         Duration       Pulse    Maxpulse    Calories
# count  32.000000   32.000000   32.000000   32.000000
# mean   55.781250  103.500000  128.500000  304.680000
# std     7.840072    7.832933   12.998759   63.839129
# min    30.000000   90.000000  101.000000  195.100000
# 25%    56.250000  100.000000  120.000000  250.700000
# 50%    60.000000  102.500000  127.500000  300.000000
# 75%    60.000000  106.500000  132.250000  341.325000
# max    60.000000  130.000000  175.000000  479.000000

# %%
# Arreglos masivos
df.loc[7, 'Duration'] = 450

for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.loc[x, "Duration"] = 120
        
df.loc[0:7, 'Duration']
# Out:
# 0     60
# 1     60
# 2     60
# 3     45
# 4     45
# 5     60
# 6     60
# 7    120
# Name: Duration, dtype: int64

# %%
# Otra forma
df.loc[7, 'Duration'] = 450

df[df['Duration'] > 120] = 120
df.loc[0:7, 'Duration']
# Out:
# 0     60
# 1     60
# 2     60
# 3     45
# 4     45
# 5     60
# 6     60
# 7    120
# Name: Duration, dtype: int64

# %%
# Borrar las filas con problemas
df.loc[7, 'Duration'] = 450
for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.drop(x, inplace = True) 
df.loc[0:8, 'Duration']

# %% [markdown]
# Eliminando filas duplicadas

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(inplace = True)
df

# %%
# Correlacion entre columnas
df.corr()

# %% [markdown]
# ## Agrupamiento
# Al agrupar un dataframe por una columna, se crea una vista del dataframe para cada valor existente de esa columna

# %%
for key, group in df.groupby("Duration"):
    print(key)
    print(group.head(3))
# Out:
# 30
#    Duration                 Date  Pulse  Maxpulse  Calories
# 8        30  2020-12-09 00:00:00    109       133     195.1
# 45
#     Duration                 Date  Pulse  Maxpulse  Calories
# 3         45  2020-12-04 00:00:00    109       175    282.40
# 4         45  2020-12-05 00:00:00    117       148    406.00
# 18        45  2020-12-18 00:00:00     90       112    304.68
# 60
#    Duration                 Date  Pulse  Maxpulse  Calories
# 0        60  2020-12-01 00:00:00    110       130     409.1
# 1        60  2020-12-02 00:00:00    117       145     479.0
# 2        60  2020-12-03 00:00:00    103       135     340.0
# 120
#    Duration Date  Pulse  Maxpulse  Calories
# 7       120  120    120       120     120.0

# %%
# Con los grupos puede hacerse procesamiento posterior de manera directa
df.groupby("Duration")['Pulse'].mean()
# Out:
# Duration
# 30     109.000
# 45     103.000
# 60     103.375
# 120    120.000
# Name: Pulse, dtype: float64

# %%
# o de todos. Noten que el resultado es un dataframe
means = df.groupby("Duration").mean()
means
# Out:
#             Pulse    Maxpulse    Calories
# Duration
# 30        109.000  133.000000  195.100000
# 45        103.000  135.166667  294.013333
# 60        103.375  126.416667  314.053333
# 120       120.000  120.000000  120.000000

# %%
means.corr()
# Out:
#              Pulse  Maxpulse  Calories
# Pulse     1.000000 -0.745819 -0.961871
# Maxpulse -0.745819  1.000000  0.553560
# Calories -0.961871  0.553560  1.000000

# %%
# Cantidad por grupos
df.groupby("Duration")['Pulse'].count()
# Out:
# Duration
# 30      1
# 45      6
# 60     24
# 120     1
# Name: Pulse, dtype: int64

# %%
# Se puede agrupar por varias columnas de forma simultanea. 
# Para ello vamos a usar otra base de datos
dtypes = {
    "first_name": "category",
    "gender": "category",
    "type": "category",
    "state": "category",
    "party": "category",
}
data = pd.read_csv(
    "data/legislators-historical.csv",
    dtype=dtypes,
    usecols=list(dtypes) + ["birthday", "last_name"],
    parse_dates=["birthday"]
)
data.tail()
# Out:
#       last_name first_name   birthday gender type state       party
# 12053      Vela    Filemon 1963-02-13      M  rep    TX    Democrat
# 12054      Reed        Tom 1971-11-18      M  rep    NY  Republican
# 12055   Delgado    Antonio 1977-01-19      M  rep    NY    Democrat
# 12056  Walorski     Jackie 1963-08-17      F  rep    IN  Republican
# 12057     Crist    Charlie 1956-07-24      M  rep    FL    Democrat

# %%
for k, v in data.groupby(["state", "gender"]):
    print(k)
    print(v.head(2))
# Out:
# ('AK', 'M')
#      last_name first_name   birthday gender type state        party
# 6617    Waskey      Frank 1875-04-20      M  rep    AK     Democrat
# 6645      Cale     Thomas 1848-09-17      M  rep    AK  Independent
# ('AL', 'F')
#       last_name first_name   birthday gender type state     party
# 8539     Graves      Dixie 1882-07-26      F  sen    AL  Democrat
# 10101   Andrews  Elizabeth 1911-02-12      F  rep    AL  Democrat
# ('AL', 'M')
#     last_name first_name   birthday gender type state       party
# 911   Crowell       John 1780-09-18      M  rep    AL  Republican
# 990    Walker       John 1783-08-12      M  sen    AL  Republican
# ('AR', 'F')
#      last_name first_name   birthday gender type state     party
# 8012  Oldfield      Pearl 1876-12-02      F  rep    AR  Democrat
# 8237     Wingo  Effiegene 1883-04-13      F  rep    AR  Democrat
# ('AR', 'M')
#      last_name first_name   birthday gender type state party
# 1000     Bates      James 1788-08-25      M  rep    AR   NaN
# 1278    Conway      Henry 1793-03-18      M  rep    AR   NaN
# ('AS', 'M')
#           last_name first_name   birthday gender type state     party
# 10795         Sunia       Fofó 1937-03-13      M  rep    AS  Democrat
# 11752  Faleomavaega        Eni 1943-08-15      M  rep    AS  Democrat
# ('AZ', 'F')
#       last_name first_name   birthday gender type state     party
# 8429   Greenway   Isabella 1886-03-22      F  rep    AZ  Democrat
# 11015   English      Karan 1949-03-23      F  rep    AZ  Democrat
# ('AZ', 'M')
#      last_name first_name   birthday gender type state       party
# 3672    Poston    Charles 1825-04-20      M  rep    AZ  Republican
# 3723   Goodwin       John 1824-10-18      M  rep    AZ  Republican
# ('CA', 'F')
#      last_name first_name   birthday gender type state       party
# 7731     Nolan        Mae 1886-09-20      F  rep    CA  Republican
# 8444      Kahn   Florence 1866-11-09      F  rep    CA  Republican
# ('CA', 'M')
#      last_name first_name   birthday gender type state        party
# 2648   Gilbert     Edward        NaT      M  rep    CA     Democrat
# 2740    Wright     George 1816-06-04      M  rep    CA  Independent
# ('CO', 'F')
#        last_name first_name   birthday gender type state       party
# 11149  Schroeder   Patricia 1940-07-30      F  rep    CO    Democrat
# 11501   Musgrave    Marilyn 1949-01-27      F  rep    CO  Republican
# ('CO', 'M')
#      last_name first_name   birthday gender type state  \
# 3612    Bennet      Hiram 1826-09-02      M  rep    CO
# 3931  Bradford      Allen 1815-07-23      M  rep    CO
#
#                         party
# 3612  Conservative Republican
# 3931               Republican
# ('CT', 'F')
#       last_name first_name   birthday gender type state       party
# 9013       Luce      Clare 1903-03-10      F  rep    CT  Republican
# 9291  Woodhouse      Chase 1890-03-03      F  rep    CT    Democrat
# ('CT', 'M')
#      last_name first_name   birthday gender type state               party
# 14  Huntington   Benjamin 1736-04-19      M  rep    CT                 NaN
# 16     Johnson    William 1727-10-07      M  sen    CT  Pro-Administration
# ('DC', 'M')
#       last_name first_name   birthday gender type state       party
# 4230    Chipman     Norton 1834-03-07      M  rep    DC  Republican
# 10819  Fauntroy     Walter 1933-02-06      M  rep    DC    Democrat
# ('DE', 'M')
#    last_name first_name   birthday gender type state                party
# 0    Bassett    Richard 1745-04-02      M  sen    DE  Anti-Administration
# 40      Read     George 1733-09-18      M  sen    DE                  NaN
# ('DK', 'M')
#      last_name first_name   birthday gender type state     party
# 3640     Jayne    William 1826-10-08      M  rep    DK       NaN
# 3685      Todd       John 1814-04-04      M  rep    DK  Democrat
# ('FL', 'F')
#       last_name first_name   birthday gender type state       party
# 8189       Owen       Ruth 1885-10-02      F  rep    FL    Democrat
# 10607   Hawkins      Paula 1927-01-24      F  sen    FL  Republican
# ('FL', 'M')
#       last_name first_name   birthday gender type state party
# 1030  Hernández     Joseph 1788-05-26      M  rep    FL   NaN
# 1089       Call    Richard 1792-10-24      M  rep    FL   NaN
# ('GA', 'F')
#      last_name first_name   birthday gender type state     party
# 7671    Felton    Rebecca 1835-06-10      F  sen    GA  Democrat
# 8661     Gibbs   Florence 1890-04-04      F  rep    GA  Democrat
# ('GA', 'M')
#    last_name first_name   birthday gender type state                party
# 8        Few    William 1748-06-08      M  sen    GA  Anti-Administration
# 20   Mathews     George 1739-08-30      M  rep    GA                  NaN
# ('GU', 'F')
#       last_name first_name   birthday gender type state     party
# 11886  Bordallo  Madeleine 1933-05-31      F  rep    GU  Democrat
# ('GU', 'M')
#       last_name first_name   birthday gender type state       party
# 10702   Won Pat    Antonio 1908-12-10      M  rep    GU    Democrat
# 10872      Blaz        Ben 1928-02-14      M  rep    GU  Republican
# ('HI', 'F')
#         last_name first_name   birthday gender type state       party
# 9488   Farrington       Mary 1898-05-30      F  rep    HI  Republican
# 10846       Saiki   Patricia 1930-05-28      F  rep    HI  Republican
# ('HI', 'M')
#      last_name first_name   birthday gender type state       party
# 6393    Wilcox     Robert 1855-02-15      M  rep    HI         NaN
# 7522   Baldwin      Henry 1871-01-12      M  rep    HI  Republican
# ('IA', 'F')
#         last_name first_name   birthday gender type state     party
# 12031  Finkenauer       Abby 1988-12-27      F  rep    IA  Democrat
# ('IA', 'M')
#      last_name first_name   birthday gender type state     party
# 1930   Chapman    William 1808-08-11      M  rep    IA  Democrat
# 2390  Hastings   Serranus 1813-11-22      M  rep    IA  Democrat
# ('ID', 'F')
#             last_name first_name   birthday gender type state       party
# 9753            Pfost     Gracie 1906-03-12      F  rep    ID    Democrat
# 11230  Chenoweth-Hage      Helen 1938-01-27      F  rep    ID  Republican
# ('ID', 'M')
#      last_name first_name   birthday gender type state       party
# 3691   Wallace    William 1811-07-19      M  rep    ID  Republican
# 3844  Holbrook     Edward 1836-05-06      M  rep    ID    Democrat
# ('IL', 'F')
#       last_name first_name   birthday gender type state       party
# 7578       Huck  Winnifred 1882-09-14      F  rep    IL  Republican
# 7999  McCormick       Ruth 1880-03-27      F  rep    IL  Republican
# ('IL', 'M')
#       last_name first_name   birthday gender type state party
# 595        Bond   Shadrack 1773-11-24      M  rep    IL   NaN
# 772  Stephenson   Benjamin        NaT      M  rep    IL   NaN
# ('IN', 'F')
#      last_name first_name   birthday gender type state       party
# 8555   Jenckes   Virginia 1877-11-06      F  rep    IN    Democrat
# 9559    Harden      Cecil 1894-11-21      F  rep    IN  Republican
# ('IN', 'M')
#     last_name first_name   birthday gender type state       party
# 431     Parke   Benjamin 1777-09-22      M  rep    IN         NaN
# 984    Taylor     Waller        NaT      M  sen    IN  Republican
# ('KS', 'F')
#                  last_name first_name   birthday gender type state     party
# 8345   O’Loughlin McCarthy    Kathryn 1894-04-24      F  rep    KS  Democrat
# 10424                 Keys     Martha 1930-08-10      F  rep    KS  Democrat
# ('KS', 'M')
#       last_name first_name   birthday gender type state       party
# 3161  Whitfield       John 1818-03-11      M  rep    KS    Democrat
# 3420    Parrott     Marcus 1828-10-27      M  rep    KS  Republican
# ('KY', 'F')
#       last_name first_name   birthday gender type state       party
# 7993    Langley  Katherine 1888-02-14      F  rep    KY  Republican
# 11430   Northup       Anne 1948-01-22      F  rep    KY  Republican
# ('KY', 'M')
#     last_name   first_name birthday gender type state                party
# 55    Edwards         John      NaT      M  sen    KY  Anti-Administration
# 113   Greenup  Christopher      NaT      M  rep    KY           Republican
# ('LA', 'F')
#       last_name first_name   birthday gender type state     party
# 8492       Long       Rose 1892-04-08      F  sen    LA  Democrat
# 10187   Edwards     Elaine 1929-03-08      F  sen    LA  Democrat
# ('LA', 'M')
#      last_name first_name birthday gender type state       party
# 584  Destréhan       Jean      NaT      M  sen    LA     Unknown
# 585   Magruder      Allan      NaT      M  sen    LA  Republican
# ('MA', 'F')
#       last_name first_name   birthday gender type state       party
# 9677     Rogers      Edith 1881-03-19      F  rep    MA  Republican
# 10143     Hicks     Louise 1916-10-16      F  rep    MA    Democrat
# ('MA', 'M')
#    last_name first_name   birthday gender type state               party
# 6     Dalton   Tristram 1738-05-28      M  sen    MA  Pro-Administration
# 12     Grout   Jonathan 1737-07-23      M  rep    MA                 NaN
# ('MD', 'F')
#       last_name first_name   birthday gender type state     party
# 8738      Byron  Katharine 1903-10-25      F  rep    MD  Democrat
# 10535  Spellman     Gladys 1918-03-01      F  rep    MD  Democrat
# ('MD', 'M')
#   last_name first_name   birthday gender type state party
# 3   Carroll     Daniel 1730-07-22      M  rep    MD   NaN
# 5    Contee   Benjamin        NaT      M  rep    MD   NaN
# ('ME', 'F')
#       last_name first_name   birthday gender type state       party
# 10021     Smith   Margaret 1897-12-14      F  sen    ME  Republican
# 11643     Snowe    Olympia 1947-02-21      F  sen    ME  Republican
# ('ME', 'M')
#      last_name first_name   birthday gender type state       party
# 1018      Dane     Joseph 1778-10-25      M  rep    ME  Federalist
# 1028    Harris       Mark 1779-01-27      M  rep    ME  Republican
# ('MI', 'F')
#        last_name first_name   birthday gender type state       party
# 9518    Thompson       Ruth 1887-09-15      F  rep    MI  Republican
# 10226  Griffiths     Martha 1912-01-29      F  rep    MI    Democrat
# ('MI', 'M')
#      last_name first_name   birthday gender type state party
# 1061    Sibley    Solomon 1769-10-07      M  rep    MI   NaN
# 1132   Richard    Gabriel 1767-10-15      M  rep    MI   NaN
# ('MN', 'F')
#       last_name first_name   birthday gender type state     party
# 9575    Knutson       Coya 1912-08-22      F  rep    MN  Democrat
# 10472  Humphrey     Muriel 1912-02-20      F  sen    MN  Democrat
# ('MN', 'M')
#       last_name first_name   birthday gender type state     party
# 2864     Sibley      Henry 1811-02-20      M  rep    MN       NaN
# 3239  Kingsbury    William 1828-06-04      M  rep    MN  Democrat
# ('MO', 'F')
#       last_name first_name   birthday gender type state     party
# 10377  Sullivan     Leonor 1902-08-21      F  rep    MO  Democrat
# 10916      Horn       Joan 1936-10-18      F  rep    MO  Democrat
# ('MO', 'M')
#      last_name first_name   birthday gender type state party
# 627  Hempstead     Edward 1780-06-03      M  rep    MO   NaN
# 712     Easton      Rufus 1774-05-04      M  rep    MO   NaN
# ('MS', 'M')
#     last_name  first_name   birthday gender type state party
# 256    Greene      Thomas 1758-02-26      M  rep    MS   NaN
# 260    Hunter  Narsworthy        NaT      M  rep    MS   NaN
# ('MT', 'F')
#      last_name first_name   birthday gender type state       party
# 8818    Rankin  Jeannette 1880-06-11      F  rep    MT  Republican
# ('MT', 'M')
#       last_name first_name   birthday gender type state     party
# 3754     McLean     Samuel 1826-08-07      M  rep    MT  Democrat
# 3939  Cavanaugh      James 1823-07-04      M  rep    MT  Democrat
# ('NC', 'F')
#       last_name first_name   birthday gender type state     party
# 9034      Pratt      Eliza 1902-03-05      F  rep    NC  Democrat
# 11285   Clayton        Eva 1934-09-16      F  rep    NC  Democrat
# ('NC', 'M')
#    last_name first_name   birthday gender type state               party
# 13   Hawkins   Benjamin 1754-08-15      M  sen    NC  Pro-Administration
# 17  Johnston     Samuel 1733-12-15      M  sen    NC  Pro-Administration
# ('ND', 'F')
#       last_name first_name   birthday gender type state     party
# 10993   Burdick    Jocelyn 1922-02-06      F  sen    ND  Democrat
# 11937  Heitkamp      Heidi 1955-10-30      F  sen    ND  Democrat
# ('ND', 'M')
#      last_name first_name   birthday gender type state       party
# 5382     Casey      Lyman 1837-05-06      M  sen    ND  Republican
# 5477    Pierce    Gilbert 1839-01-11      M  sen    ND  Republican
# ('NE', 'F')
#      last_name first_name   birthday gender type state       party
# 9462      Abel      Hazel 1888-07-10      F  sen    NE  Republican
# 9464   Bowring        Eva 1892-01-09      F  sen    NE  Republican
# ('NE', 'M')
#      last_name first_name   birthday gender type state     party
# 2952  Giddings   Napoleon 1816-01-02      M  rep    NE  Democrat
# 3066   Chapman       Bird 1821-08-24      M  rep    NE  Democrat
# ('NH', 'F')
#          last_name first_name   birthday gender type state       party
# 11802       Ayotte      Kelly 1968-06-27      F  sen    NH  Republican
# 11957  Shea-Porter      Carol 1952-12-02      F  rep    NH    Democrat
# ('NH', 'M')
#     last_name first_name   birthday gender type state       party
# 99    Wingate      Paine 1739-05-14      M  rep    NH         NaN
# 120   Langdon       John 1741-06-26      M  sen    NH  Republican
# ('NJ', 'F')
#       last_name first_name   birthday gender type state       party
# 9266     Norton       Mary 1875-03-07      F  rep    NJ    Democrat
# 10127     Dwyer   Florence 1902-07-04      F  rep    NJ  Republican
# ('NJ', 'M')
#    last_name first_name   birthday gender type state               party
# 7      Elmer   Jonathan 1745-11-29      M  sen    NJ  Pro-Administration
# 23  Paterson    William 1745-12-24      M  sen    NJ  Pro-Administration
# ('NM', 'F')
#       last_name first_name   birthday gender type state       party
# 9153       Lusk    Georgia 1893-05-12      F  rep    NM    Democrat
# 11519    Wilson    Heather 1960-12-30      F  rep    NM  Republican
# ('NM', 'M')
#       last_name first_name   birthday gender type state     party
# 2883  Weightman    Richard 1816-12-28      M  rep    NM  Democrat
# 3418      Otero     Miguel 1829-06-21      M  rep    NM       NaN
# ('NV', 'F')
#         last_name first_name   birthday gender type state       party
# 11157  Vucanovich    Barbara 1921-06-22      F  rep    NV  Republican
# 11655     Berkley    Shelley 1951-01-20      F  rep    NV    Democrat
# ('NV', 'M')
#         last_name first_name   birthday gender type state       party
# 3508  Cradlebaugh       John 1819-02-22      M  rep    NV         NaN
# 3662         Mott     Gordon 1812-10-21      M  rep    NV  Republican
# ('NY', 'F')
#      last_name first_name   birthday gender type state       party
# 8195     Pratt       Ruth 1877-08-24      F  rep    NY  Republican
# 8282    Clarke     Marian 1880-07-29      F  rep    NY  Republican
# ('NY', 'M')
#          last_name first_name   birthday gender type state party
# 9            Floyd    William 1734-12-17      M  rep    NY   NaN
# 26  Van Rensselaer   Jeremiah 1738-08-27      M  rep    NY   NaN
# ('OH', 'F')
#       last_name first_name   birthday gender type state       party
# 9985     Bolton    Frances 1885-03-29      F  rep    OH  Republican
# 10554  Ashbrook       Jean 1934-09-21      F  rep    OH  Republican
# ('OH', 'M')
#     last_name first_name   birthday gender type state       party
# 226  McMillan    William 1764-03-02      M  rep    OH         NaN
# 254   Fearing       Paul 1762-02-28      M  rep    OH  Federalist
# ('OK', 'F')
#        last_name first_name   birthday gender type state       party
# 7641   Robertson      Alice 1854-01-02      F  rep    OK  Republican
# 11552     Fallin       Mary 1954-12-09      F  rep    OK  Republican
# ('OK', 'M')
#      last_name first_name   birthday gender type state        party
# 5599    Harvey      David 1845-03-20      M  rep    OK   Republican
# 6058  Callahan      James 1852-12-19      M  rep    OK  Free Silver
# ('OL', 'M')
#     last_name first_name   birthday gender type state party
# 404     Clark     Daniel        NaT      M  rep    OL   NaN
# 503   Poydras     Julien 1740-04-03      M  rep    OL   NaN
# ('OR', 'F')
#       last_name first_name   birthday gender type state     party
# 8553   Honeyman        Nan 1881-07-15      F  rep    OR  Democrat
# 9690  Neuberger    Maurine 1907-01-09      F  sen    OR  Democrat
# ('OR', 'M')
#      last_name first_name   birthday gender type state     party
# 2726  Thurston     Samuel 1816-04-15      M  rep    OR  Democrat
# 3396      Lane     Joseph 1801-12-14      M  sen    OR  Democrat
# ('PA', 'F')
#      last_name first_name   birthday gender type state     party
# 8733    Boland   Veronica 1899-03-18      F  rep    PA  Democrat
# 9474  Buchanan       Vera 1902-07-20      F  rep    PA  Democrat
# ('PA', 'M')
#    last_name first_name   birthday gender type state                party
# 4     Clymer     George 1739-03-16      M  rep    PA                  NaN
# 19    Maclay    William 1737-07-20      M  sen    PA  Anti-Administration
# ('PI', 'M')
#              last_name first_name   birthday gender type state party
# 6833            Ocampo      Pablo 1853-01-25      M  rep    PI   NaN
# 6937  Legarda Y Tuason     Benito 1853-09-27      M  rep    PI   NaN
# ('PR', 'M')
#       last_name first_name   birthday gender type state       party
# 6424    Degetau   Federico 1862-12-05      M  rep    PR  Republican
# 6809  Larrinaga      Tulio 1847-01-15      M  rep    PR    Unionist
# ('RI', 'F')
#        last_name first_name   birthday gender type state       party
# 10848  Schneider   Claudine 1947-03-25      F  rep    RI  Republican
# ('RI', 'M')
#     last_name first_name   birthday gender type state       party
# 61   Bradford    William 1729-11-04      M  sen    RI  Federalist
# 105    Bourne   Benjamin 1755-09-09      M  rep    RI  Federalist
# ('SC', 'F')
#      last_name first_name   birthday gender type state     party
# 8535    Gasque  Elizabeth 1886-02-26      F  rep    SC  Democrat
# 8687  McMillan      Clara 1894-08-17      F  rep    SC  Democrat
# ('SC', 'M')
#    last_name first_name   birthday gender type state               party
# 2      Burke    Aedanus 1743-06-16      M  rep    SC                 NaN
# 15     Izard      Ralph        NaT      M  sen    SC  Pro-Administration
# ('SD', 'F')
#       last_name first_name   birthday gender type state       party
# 8622       Pyle     Gladys 1890-10-04      F  sen    SD  Republican
# 9205  Bushfield       Vera 1889-08-09      F  sen    SD  Republican
# ('SD', 'M')
#      last_name first_name   birthday gender type state       party
# 5421   Gifford      Oscar 1842-10-20      M  rep    SD  Republican
# 5460     Moody     Gideon 1832-10-16      M  sen    SD  Republican
# ('TN', 'F')
#      last_name first_name   birthday gender type state       party
# 8109    Eslick      Willa 1878-09-08      F  rep    TN    Democrat
# 9758     Reece     Louise 1898-11-06      F  rep    TN  Republican
# ('TN', 'M')
#     last_name first_name   birthday gender type state       party
# 141     White      James 1749-06-16      M  rep    TN         NaN
# 142    Blount    William 1749-03-26      M  sen    TN  Republican
# ('TX', 'F')
#       last_name first_name   birthday gender type state     party
# 9963     Thomas       Lera 1900-08-03      F  rep    TX  Democrat
# 10422    Jordan    Barbara 1936-02-21      F  rep    TX  Democrat
# ('TX', 'M')
#      last_name first_name   birthday gender type state     party
# 2567  Pilsbury    Timothy 1789-04-12      M  rep    TX  Democrat
# 2669   Kaufman      David 1813-12-18      M  rep    TX  Democrat
# ('UT', 'F')
#       last_name first_name   birthday gender type state     party
# 9302     Bosone       Reva 1895-04-02      F  rep    UT  Democrat
# 11074  Shepherd      Karen 1940-07-05      F  rep    UT  Democrat
# ('UT', 'M')
#       last_name first_name   birthday gender type state     party
# 3482  Bernhisel       John 1799-07-23      M  rep    UT      Whig
# 3645     Kinney       John 1816-04-02      M  rep    UT  Democrat
# ('VA', 'F')
#       last_name first_name   birthday gender type state       party
# 11006     Byrne     Leslie 1946-10-27      F  rep    VA    Democrat
# 11463     Davis     Jo Ann 1950-06-29      F  rep    VA  Republican
# ('VA', 'M')
#    last_name  first_name   birthday gender type state                party
# 1      Bland  Theodorick 1742-03-21      M  rep    VA                  NaN
# 11   Grayson     William        NaT      M  sen    VA  Anti-Administration
# ('VI', 'F')
#          last_name first_name   birthday gender type state     party
# 11749  Christensen      Donna 1945-09-19      F  rep    VI  Democrat
# ('VI', 'M')
#       last_name first_name   birthday gender type state       party
# 10494     Evans     Melvin 1917-08-07      M  rep    VI  Republican
# 11086   de Lugo        Ron 1930-08-02      M  rep    VI    Democrat
# ('VT', 'M')
#    last_name first_name   birthday gender type state                party
# 41  Robinson      Moses 1741-03-22      M  sen    VT  Anti-Administration
# 86     Niles  Nathaniel 1741-04-03      M  rep    VT                  NaN
# ('WA', 'F')
#       last_name first_name   birthday gender type state       party
# 10070       May  Catherine 1914-05-18      F  rep    WA  Republican
# 10234    Hansen      Julia 1907-06-14      F  rep    WA    Democrat
# ('WA', 'M')
#       last_name first_name   birthday gender type state     party
# 2977  Lancaster   Columbia 1803-08-26      M  rep    WA  Democrat
# 3050   Anderson      James 1822-02-16      M  rep    WA  Democrat
# ('WI', 'M')
#      last_name first_name   birthday gender type state     party
# 2409    Martin     Morgan 1805-03-31      M  rep    WI  Democrat
# 2502   Darling      Mason 1801-05-18      M  rep    WI  Democrat
# ('WV', 'F')
#      last_name first_name   birthday gender type state     party
# 9832       Kee      Maude 1895-06-07      F  rep    WV  Democrat
# ('WV', 'M')
#        last_name first_name   birthday gender type state  \
# 3613       Blair      Jacob 1821-04-11      M  rep    WV
# 3688  Van Winkle      Peter 1808-09-07      M  sen    WV
#
#                        party
# 3613  Unconditional Unionist
# 3688              Republican
# ('WY', 'F')
#       last_name first_name   birthday gender type state       party
# 11461     Cubin    Barbara 1946-11-30      F  rep    WY  Republican
# ('WY', 'M')
#      last_name first_name   birthday gender type state       party
# 4007  Nuckolls    Stephen 1825-08-16      M  rep    WY    Democrat
# 4136     Jones    William 1842-02-20      M  rep    WY  Republican

# %%
# Contemos por estado y genero
data.groupby(["state", "gender"])["last_name"].count()
# Out:
# state  gender
# AK     F           0
#        M          17
# AL     F           4
#        M         205
# AR     F           5
#                 ...
# WI     M         198
# WV     F           1
#        M         119
# WY     F           1
#        M          39
# Name: last_name, Length: 116, dtype: int64

# %%
# El orden importa!
data.groupby(["gender", "state"])["last_name"].count()
# Out:
# gender  state
# F       AK         0
#         AL         4
#         AR         5
#         AS         0
#         AZ         4
#                 ...
# M       VT       115
#         WA        91
#         WI       198
#         WV       119
#         WY        39
# Name: last_name, Length: 116, dtype: int64

# %%
# Los indices que devuelve son multiindices ...
data.groupby(["state", "gender"])["last_name"].count().index
# Out:
# MultiIndex([('AK', 'F'),
#             ('AK', 'M'),
#             ('AL', 'F'),
#             ('AL', 'M'),
#             ('AR', 'F'),
#             ('AR', 'M'),
#             ('AS', 'F'),
#             ('AS', 'M'),
#             ('AZ', 'F'),
#             ('AZ', 'M'),
#             ...
#             ('VT', 'F'),
#             ('VT', 'M'),
#             ('WA', 'F'),
#             ('WA', 'M'),
#             ('WI', 'F'),
#             ('WI', 'M'),
#             ('WV', 'F'),
#             ('WV', 'M'),
#             ('WY', 'F'),
#             ('WY', 'M')],
#            names=['state', 'gender'], length=116)

# %%
# El resultado puede obtenerse sin usar indices, al estilo SQL
data.groupby(["state", "gender"], as_index=False)["last_name"].count()
# Out:
#     state gender  last_name
# 0      AK      F          0
# 1      AK      M         17
# 2      AL      F          4
# 3      AL      M        205
# 4      AR      F          5
# ..    ...    ...        ...
# 111    WI      M        198
# 112    WV      F          1
# 113    WV      M        119
# 114    WY      F          1
# 115    WY      M         39
#
# [116 rows x 3 columns]

# %% [markdown]
# ## Visualizacion de datos

# %%
import matplotlib.pyplot as plt
df = pd.read_csv("data/cardio2.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# Ploteo muuuy simple
df.plot()
plt.show()

# %%
# Un scatter plot
df.plot(kind = 'scatter', x = 'Pulse', y = 'Calories')
plt.show()

# %%
# Correlación ....
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
plt.show()

# %%
df.plot(kind = 'scatter', x = 'Maxpulse', y = 'Duration')
plt.show()

# %%
# Histogramas
df['Duration'].plot(kind='hist')
plt.show()

# %%
# controlando los bins
df['Duration'].plot(kind='hist', bins=20)
plt.show()
